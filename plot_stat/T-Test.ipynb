# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
score1 = np.array([12,11,4,3,7,14,9,8,13,6])
plt.subplot(211)
plt.hist(score1,bins=15,color='r')
score2 = np.array([17,16,12,6,18,20,19,17,15,16])
plt.subplot(212)
plt.hist(score2,bins=15,color='g');

# %%
stats.ttest_ind(score1,score2)
# Out:
# TtestResult(statistic=np.float64(-3.950928506765691), pvalue=np.float64(0.0009368378292774322), df=np.float64(18.0))

# %%
#Anova
