# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
l = ['Python','Java','C++']
s = [ 200 , 150 , 100 ]
c = [ 'green','red','yellow']

# %%
plt.pie(s,labels=l,colors=c)
# Out:
# ([<matplotlib.patches.Wedge at 0x7448ac65b800>,
#   <matplotlib.patches.Wedge at 0x7448ac65b4d0>,
#   <matplotlib.patches.Wedge at 0x7448ac65bfe0>],
#  [Text(0.19101291029689543, 1.0832885433253276, 'Python'),
#   Text(-0.8426489242659605, -0.7070663267568467, 'Java'),
#   Text(0.8426491097070433, -0.7070661057566878, 'C++')])

# %%
plt.pie(s,labels=l,colors=c,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7448aa31a390>,
#   <matplotlib.patches.Wedge at 0x7448ac690a10>,
#   <matplotlib.patches.Wedge at 0x7448aa31ae70>],
#  [Text(0.19101291029689543, 1.0832885433253276, 'Python'),
#   Text(-0.8426489242659605, -0.7070663267568467, 'Java'),
#   Text(0.8426491097070433, -0.7070661057566878, 'C++')],
#  [Text(0.10418886016194295, 0.5908846599956332, '44.4%'),
#   Text(-0.45962668596325107, -0.3856725418673709, '33.3%'),
#   Text(0.45962678711293264, -0.38567242132182966, '22.2%')])

# %%
plt.pie(s,labels=l,colors=c ,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7448aa3617f0>,
#   <matplotlib.patches.Wedge at 0x7448aa361730>,
#   <matplotlib.patches.Wedge at 0x7448aa361e20>],
#  [Text(-1.0832885061337203, 0.19101312122095906, 'Python'),
#   Text(0.7070662631386209, -0.8426489776479805, 'Java'),
#   Text(0.7070663702780942, 0.8426488877472997, 'C++')])

# %%
plt.pie(s,labels=l,colors=c,explode=(0.1,0,0),shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7448aa343740>,
#   <matplotlib.patches.Wedge at 0x7448aa3429c0>,
#   <matplotlib.patches.Wedge at 0x7448aa3c47d0>],
#  [Text(0.20837772032388593, 1.1817693199912664, 'Python'),
#   Text(-0.8426489242659605, -0.7070663267568467, 'Java'),
#   Text(0.8426491097070433, -0.7070661057566878, 'C++')],
#  [Text(0.12155367018893345, 0.6893654366615721, '44.4%'),
#   Text(-0.45962668596325107, -0.3856725418673709, '33.3%'),
#   Text(0.45962678711293264, -0.38567242132182966, '22.2%')])

# %%
s = pd.Series(3*np.random.rand(3),index=['a','b','c'],name='series')
s
# Out:
# a    1.290617
# b    1.306629
# c    1.263732
# Name: series, dtype: float64

# %%
s.plot.pie(autopct='%1.1f%%',fontsize=25,figsize=(7,7));

# %%
df = pd.DataFrame(3*np.random.rand(4,2),index=['a','b','c','d'],columns=['x','y'])
df
# Out:
#           x         y
# a  2.600396  2.615002
# b  1.035613  1.023200
# c  0.472266  2.785769
# d  0.986847  0.815006

# %%
df.plot.pie(subplots=True,figsize=(15,8))
plt.savefig('./plot.png')
