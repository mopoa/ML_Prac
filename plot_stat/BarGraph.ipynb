# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
grade = ['A','B','C','D','E']

# %%
n = [5,10,8,3,2]

# %%
k = [0,1,2,3,4]

# %%
plt.bar(grade,n,color='green')
plt.xlabel('Grade')
plt.ylabel('No of student')
# Out:
# Text(0, 0.5, 'No of student')

# %% [markdown]
# ScatterPlot

# %%
x = np.array([-3,-2,-1,0,1,2,3])
y = np.array([9,4,1,0,1,4,9])

# %%
plt.scatter(x,y,c='r');

# %% [markdown]
# Histogram

# %%
data = np.array([3,3,5,6,7,7,7,8,9,9,10,10,10,11,12,12,14,15,16,17,18,19,19,20])

# %%
plt.xlabel('value')
plt.ylabel('frequency')
plt.hist(data,bins=5, color='green',edgecolor='black')
plt.show();

# %%
x = 100 + 15 *np.random.randn(1000)

# %%
n,bins,_ = plt.hist(x,20,edgecolor='black')
plt.show()

# %%
# import matplotlib.mlab as mlab
# y =mlab.(bins,100,15)
# plt.plot(bins,y,'r')
